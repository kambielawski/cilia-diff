# %%
from viz import visualize, visualize_actuator_flat, plot_single_particle
import pickle

# %%
file_path = './experiments/exp_example/exp1_parameters/exp1_parameters_positions.pkl'
with open(file_path, 'rb') as pf:
    time_series, actuator_ids = pickle.load(pf)

# %%
visualize_actuator_flat(time_series, actuator_ids)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
plot_single_particle(time_series[:40, 0, :])
